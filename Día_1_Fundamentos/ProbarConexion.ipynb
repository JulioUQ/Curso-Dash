# %%
# %load_ext autoreload
# %autoreload 2

# Proporciona funciones para interactuar con el sistema operativo (como rutas de archivos).
import os  

# Permite modificar aspectos del entorno de ejecución de Python, como la lista de rutas de búsqueda de módulos (sys.path).
import sys 

# En notebooks, usa la ruta del notebook actual
root_dir = os.path.abspath('..')  # Sube un nivel desde /notebooks/
sys.path.append(root_dir)

import pandas as pd
import geopandas as gpd
pd.set_option('display.float_format', '{:.2f}'.format)
pd.set_option('display.max_columns', None)

# Importa las funciones personalizadas desde utils.
import utils.functions_Python_BBDD as f

# %%
query = "SELECT TOP 10* FROM cm.resumen_flota"
df_buques = f.ejecutar_consulta_sql(query, database_key="SGP_CUADROSMANDO")

# Mostrar las primeras filas del DataFrame resultante
df_buques.head()
# Out:
#    IdBuque           CFR  Año Construccion  Edad Motivo Alta Censo  \
# 0    26241  ESP000000279              1970    54     Alta en Censo
# 1    26281  ESP000000334              1960    64     Alta en Censo
# 2    26293  ESP000000348              1978    43     Alta en Censo
# 3    26311  ESP000000371              1978    40     Alta en Censo
# 4    26317  ESP000000377              1969    55     Alta en Censo
#
#            Fecha Alta Censo  Eslora Total  Eslora PP  Arqueo GT  \
# 0  1989-05-10 00:00:00.0000         28.15      26.01     238.00
# 1  1989-05-10 00:00:00.0000          8.55        NaN       3.05
# 2  1989-05-10 00:00:00.0000         28.00        NaN     112.00
# 3  1989-05-10 00:00:00.0000         28.00        NaN      96.97
# 4  1989-05-10 00:00:00.0000         17.78      14.25      22.89
#
#   Material del Casco Tipo Propulsion  Potencia KW  Potencia Auxiliar KW  \
# 0              Acero     Intra Borda       485.43                 89.73
# 1             Madera     Intra Borda        17.65                  0.00
# 2              Acero     Intra Borda       563.24                  7.35
# 3              Acero     Intra Borda       514.71                  5.88
# 4              Acero     Intra Borda       294.20                 11.03
#
#   Tipo Combustible    Estado Actual           Fecha de Estado  idpuertobase  \
# 0          Gasóleo  Alta Definitiva  1989-05-10 00:00:00.0000          5664
# 1          Gasóleo  Alta Definitiva  1989-05-10 00:00:00.0000          5664
# 2          Gasóleo  Alta Definitiva  1989-05-10 00:00:00.0000          6271
# 3          Gasóleo  Alta Definitiva  1989-05-10 00:00:00.0000          6271
# 4          Gasóleo  Alta Definitiva  1989-05-10 00:00:00.0000          6334
#
#             Puerto Base Provincia Puerto Base  \
# 0                Burela                  LUGO
# 1                Burela                  LUGO
# 2             Tarragona             TARRAGONA
# 3             Tarragona             TARRAGONA
# 4  Vilanova y la Geltrú             BARCELONA
#
#                                 Censo por Modalidad  IdCenso  IdTipoEstado  \
# 0  ARTES FIJAS EN ZONAS CIEM VB, VI,VII y VIIIabde.       33             1
# 1                    ARTES MENORES EN CANTABRICO NW        6             1
# 2              ARRASTRE DE FONDO EN EL MEDITERRANEO       14             1
# 3              ARRASTRE DE FONDO EN EL MEDITERRANEO       14             1
# 4                          CERCO EN EL MEDITERRANEO       12             1
#
#    IdCCAAPuertoBase                CALADERO                       SUBCALADERO  \
# 0                11  2.CALADERO COMUNITARIO  ZONAS CIEM VB, VI,VII y VIIIabde
# 1                11     1.CALADERO NACIONAL                     CANTABRICO NW
# 2                 9     1.CALADERO NACIONAL                      MEDITERRANEO
# 3                 9     1.CALADERO NACIONAL                      MEDITERRANEO
# 4                 9     1.CALADERO NACIONAL                      MEDITERRANEO
#
#    esfuerzo
# 0       279
# 1       137
# 2       166
# 3       166
# 4       203
